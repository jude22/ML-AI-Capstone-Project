# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import SymLogNorm
from IPython.display import clear_output
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from scipy.optimize import minimize
from scipy.stats import norm

# %%
#Function 1
input_data_1 = np.load('initial_data/function_1/initial_inputs.npy')
output_data_1 = np.load('initial_data/function_1/initial_outputs.npy')
# include new data from week 1
input_data_1 = np.append(input_data_1, [[0.838384, 0.767677]], axis=0)
output_data_1 = np.append(output_data_1, -6.893705068847273e-45)

# %%
print(input_data_1)
print(input_data_1.shape)
# Out:
# [[0.31940389 0.76295937]
#  [0.57432921 0.8798981 ]
#  [0.73102363 0.73299988]
#  [0.84035342 0.26473161]
#  [0.65011406 0.68152635]
#  [0.41043714 0.1475543 ]
#  [0.31269116 0.07872278]
#  [0.68341817 0.86105746]
#  [0.08250725 0.40348751]
#  [0.88388983 0.58225397]
#  [0.838384   0.767677  ]]
# (11, 2)

# %%
print(output_data_1)
print(output_data_1.shape)
print(np.sort(output_data_1))
# Out:
# [ 1.32267704e-079  1.03307824e-046  7.71087511e-016  3.34177101e-124
#  -3.60606264e-003 -2.15924904e-054 -2.08909327e-091  2.53500115e-040
#   3.60677119e-081  6.22985647e-048 -6.89370507e-045]
# (11,)
# [-3.60606264e-003 -6.89370507e-045 -2.15924904e-054 -2.08909327e-091
#   3.34177101e-124  3.60677119e-081  1.32267704e-079  6.22985647e-048
#   1.03307824e-046  2.53500115e-040  7.71087511e-016]

# %%
### UCB was used and tuned to be greedy or exploitative by reducing the value of sigma (post_std) through reduction in beta and adjusting
### length scale to a smaller value
### EI was also tested for comparison with UCB but yielded similar result

# %%
noise_assumption = 1e-6

rbf_lengthscale = 0.1

#Acquisition function parameter
beta = 0.4

#Define kernel of GP
kernel = RBF(length_scale=rbf_lengthscale, length_scale_bounds='fixed')
model = GaussianProcessRegressor(kernel = kernel, alpha=noise_assumption)
X = input_data_1
Y = (output_data_1 - output_data_1.mean()) / output_data_1.std() #standardise data to account for very small values

#Initialise grid for plots
grid_x = np.linspace(0, 1, len(output_data_1)**3)
grid_y = np.linspace(0, 1, len(output_data_1)**3)
xx, yy = np.meshgrid(grid_x, grid_y)
x_grid = np.c_[xx.ravel(), yy.ravel()]

model = GaussianProcessRegressor(kernel = kernel)

#Fit the GP model
model.fit(X, Y)

#Calculate the mean and standard deviation
post_mean, post_std = model.predict(x_grid, return_std=True)

# UCB acquisition
acquisition_function = post_mean + beta * post_std

"""
#EI acquisition
xi = 0.001
f_best = np.max(Y)
improvement = post_mean - f_best - xi
z = improvement / post_std
acquisition_function = improvement * norm.cdf(z) + post_std * norm.pdf(z)
acquisition_function[post_std == 0.0] = 0.0
"""
X_next = x_grid[np.argmax(acquisition_function)]

print(np.round(X_next, decimals=6))

# -----------------------
# 8. Plot UCB surface
# -----------------------
plt.contourf(xx, yy, acquisition_function.reshape(xx.shape))
plt.colorbar(label="UCB value")
plt.scatter(X[:,0], X[:,1], c='red', label="samples")
plt.scatter(X_next[0], X_next[1], c='white', edgecolor='black', s=100, label="next point")
plt.legend()
plt.title("UCB acquisition surface (2D)")
plt.show()
# Out:
# [0.766917 0.775188]

# %%
#Function 2
input_data_2 = np.load('initial_data/function_2/initial_inputs.npy')
output_data_2 = np.load('initial_data/function_2/initial_outputs.npy')
# include new data from week 1
input_data_2 = np.append(input_data_2, [[0.818182, 0.939394]], axis=0)
output_data_2 = np.append(output_data_2, 0.052187964293633496)
print(input_data_2)
print(input_data_2.shape)
print(output_data_2)
print(output_data_2.shape)

real_noise_std = 1e-6
noise_assumption = 1e-6
rbf_lengthscale = 0.1

#Acquisition function parameter
beta = 0.8 # 2 or higher to target multipeaks

#Define kernel of GP
kernel = RBF(length_scale=rbf_lengthscale, length_scale_bounds='fixed')
model = GaussianProcessRegressor(kernel = kernel, alpha=noise_assumption)

X = input_data_2
Y = output_data_2

#Initialise grid for plots
grid_x = np.linspace(0, 1, len(output_data_2)**3)
grid_y = np.linspace(0, 1, len(output_data_2)**3)
xx, yy = np.meshgrid(grid_x, grid_y)
x_grid = np.c_[xx.ravel(), yy.ravel()]
print(x_grid.shape)

model = GaussianProcessRegressor(kernel = kernel)

#Fit the GP model
model.fit(X, Y)

#Calculate the mean and standard deviation
post_mean, post_std = model.predict(x_grid, return_std=True)

# UCB acquisition
acquisition_function = post_mean + beta * post_std

X_next = x_grid[np.argmax(acquisition_function)]

print('Next: ', (np.round(X_next, decimals=6)))

# -----------------------
# 8. Plot UCB surface
# -----------------------
plt.contourf(xx, yy, acquisition_function.reshape(xx.shape))
plt.colorbar(label="UCB value")
plt.scatter(X[:,0], X[:,1], c='red', label="samples")
plt.scatter(X_next[0], X_next[1], c='white', edgecolor='black', s=100, label="next point")
plt.legend()
plt.title("UCB acquisition surface (2D)")
plt.show()
# Out:
# [[0.66579958 0.12396913]
#  [0.87779099 0.7786275 ]
#  [0.14269907 0.34900513]
#  [0.84527543 0.71112027]
#  [0.45464714 0.29045518]
#  [0.57771284 0.77197318]
#  [0.43816606 0.68501826]
#  [0.34174959 0.02869772]
#  [0.33864816 0.21386725]
#  [0.70263656 0.9265642 ]
#  [0.818182   0.939394  ]]
# (11, 2)
# [ 0.53899612  0.42058624 -0.06562362  0.29399291  0.21496451  0.02310555
#   0.24461934  0.03874902 -0.01385762  0.61120522  0.05218796]
# (11,)
# (1771561, 2)
# Next:  [0.621053 0.987218]

# %%
# Function 3
# instead of evaluating the acquisition function on a huge predefined set of candidate points (x_grid) due to input dimension > 2 (3D), 
# I directly optimize the acquisition function itself as a continuous function, therby avoiding the curse of dimensionality.
# ******** Best outcome from week 1 *****
input_data_3 = np.load('initial_data/function_3/initial_inputs.npy')
output_data_3 = np.load('initial_data/function_3/initial_outputs.npy')
# include new data from week 1
input_data_3 = np.append(input_data_3, [[0.414145, 0.390256, 0.511599]], axis=0)
output_data_3 = np.append(output_data_3, -0.010572017488314756)
print(input_data_3)
print(input_data_3.shape)
print(output_data_3)
print(output_data_3.shape)

real_noise_std = 1e-10 
noise_assumption = 1e-10
rbf_lengthscale = 0.2

#Acquisition function parameter
beta = 1.96

#Define kernel of GP
kernel = RBF(length_scale=rbf_lengthscale, length_scale_bounds='fixed')
model = GaussianProcessRegressor(kernel = kernel, alpha=noise_assumption)

X = input_data_3
y = output_data_3 # sample already negated to transform from minimisation to maximisation problem
Y = (y - y.mean()) / y.std() # scale to support tiny numbers

model = GaussianProcessRegressor(kernel = kernel)

#Fit the GP model
model.fit(X, Y)

# UCB acquisition
def acquisition(x):
    x = x.reshape(1, -1)
    post_mean, post_std = model.predict(x, return_std=True)
    return post_mean + beta * post_std


# Find Next Point
def propose_next(gp, bounds, n_restarts=5):
    best_x = None
    best_val = -np.inf

    for _ in range(n_restarts):
        x0 = np.random.uniform(0, 1, size=3)

        res = minimize(
            lambda x: -acquisition(x),  # maximise UCB
            x0=x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = acquisition(res.x)

        if val > best_val:
            best_val = val
            best_x = res.x

    return np.round(best_x, decimals=6)

# Get Next Point
bounds = [(0, 1), (0, 1), (0, 1)]
x_next = propose_next(model, bounds)
print("Next proposed input:", x_next)
# Out:
# [[0.17152521 0.34391687 0.2487372 ]
#  [0.24211446 0.64407427 0.27243281]
#  [0.53490572 0.39850092 0.17338873]
#  [0.49258141 0.61159319 0.34017639]
#  [0.13462167 0.21991724 0.45820622]
#  [0.34552327 0.94135983 0.26936348]
#  [0.15183663 0.43999062 0.99088187]
#  [0.64550284 0.39714294 0.91977134]
#  [0.74691195 0.28419631 0.22629985]
#  [0.17047699 0.6970324  0.14916943]
#  [0.22054934 0.29782524 0.34355534]
#  [0.66601366 0.67198515 0.2462953 ]
#  [0.04680895 0.23136024 0.77061759]
#  [0.60009728 0.72513573 0.06608864]
#  [0.96599485 0.86111969 0.56682913]
#  [0.414145   0.390256   0.511599  ]]
# (16, 3)
# [-0.1121222  -0.08796286 -0.11141465 -0.03483531 -0.04800758 -0.11062091
#  -0.39892551 -0.11386851 -0.13146061 -0.09418956 -0.04694741 -0.10596504
#  -0.11804826 -0.03637783 -0.05675837 -0.01057202]
# (16,)
# Next proposed input: [0.486811 0.67506  0.592334]

# %%
# Function 4
# Although treated as maximisation problem in week 1, I re-analyzed the question to further ensure that the solution
# is correct.
# ******** Best outcome from week 1 *****
input_data_4 = np.load('initial_data/function_4/initial_inputs.npy')
output_data_4 = np.load('initial_data/function_4/initial_outputs.npy')
input_data_4 = np.append(input_data_4, [[0.383229, 0.487977, 0.445785, 0.398437]], axis=0)
output_data_4 = np.append(output_data_4, -1.590305706105521)
print(input_data_4)
print(input_data_4.shape)
print(output_data_4)
print(output_data_4.shape)

real_noise_std = 1e-10 
noise_assumption = 1e-10
rbf_lengthscale = 0.2

#Acquisition function parameter
beta = 3 # 2 or higher to target multipeaks

#Define kernel of GP
kernel = RBF(length_scale=rbf_lengthscale, length_scale_bounds='fixed')
model = GaussianProcessRegressor(kernel = kernel, alpha=noise_assumption)

X = input_data_4
y = output_data_4
Y = (y - y.mean()) / y.std() # scale to support tiny numbers

model = GaussianProcessRegressor(kernel = kernel)

#Fit the GP model
model.fit(X, Y)

# UCB acquisition
def acquisition(x):
    x = x.reshape(1, -1)
    post_mean, post_std = model.predict(x, return_std=True)
    return post_mean + beta * post_std


# Find Next Point
def propose_next(gp, bounds, n_restarts=10):
    best_x = None
    best_val = -np.inf

    for _ in range(n_restarts):
        x0 = np.random.uniform(0, 1, size=4)

        res = minimize(
            lambda x: -acquisition(x),  # maximise UCB
            x0=x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = acquisition(res.x)

        if val > best_val:
            best_val = val
            best_x = res.x

    return np.round(best_x, decimals=6)

# Get Next Point
bounds = [(0, 1), (0, 1), (0, 1), (0, 1)]
x_next = propose_next(model, bounds)
print("Next proposed input:", x_next)
# Out:
# [[0.89698105 0.72562797 0.17540431 0.70169437]
#  [0.8893564  0.49958786 0.53926886 0.50878344]
#  [0.25094624 0.03369313 0.14538002 0.49493242]
#  [0.34696206 0.0062504  0.76056361 0.61302356]
#  [0.12487118 0.12977019 0.38440048 0.2870761 ]
#  [0.80130271 0.50023109 0.70664456 0.19510284]
#  [0.24770826 0.06044543 0.04218635 0.44132425]
#  [0.74670224 0.7570915  0.36935306 0.20656628]
#  [0.40066503 0.07257425 0.88676825 0.24384229]
#  [0.6260706  0.58675126 0.43880578 0.77885769]
#  [0.95713529 0.59764438 0.76611385 0.77620991]
#  [0.73281243 0.14524998 0.47681272 0.13336573]
#  [0.65511548 0.07239183 0.68715175 0.08151656]
#  [0.21973443 0.83203134 0.48286416 0.08256923]
#  [0.48859419 0.2119651  0.93917791 0.37619173]
#  [0.16713049 0.87655456 0.21723954 0.95980098]
#  [0.21691119 0.16608583 0.24137226 0.77006248]
#  [0.38748784 0.80453226 0.75179548 0.72382744]
#  [0.98562189 0.66693268 0.15678328 0.8565348 ]
#  [0.03782483 0.66485335 0.16198218 0.25392378]
#  [0.68348638 0.9027701  0.33541983 0.99948256]
#  [0.17034731 0.75695908 0.27652049 0.5312315 ]
#  [0.85965692 0.91959232 0.20613873 0.09779683]
#  [0.28213837 0.50598691 0.53053084 0.09630162]
#  [0.32607578 0.4723669  0.453192   0.10588734]
#  [0.94838936 0.89451301 0.85163782 0.55219629]
#  [0.66495539 0.04656628 0.11677747 0.79371778]
#  [0.57776561 0.42877174 0.42582587 0.24900741]
#  [0.73861301 0.48210263 0.70936644 0.50397001]
#  [0.8548108  0.49396462 0.73530997 0.80809201]
#  [0.383229   0.487977   0.445785   0.398437  ]]
# (31, 4)
# [-22.10828779 -14.60139663 -11.69993246 -16.05376511 -10.06963343
#  -15.48708254 -12.68168498 -16.02639977 -17.04923465 -12.74176599
#  -27.31639636 -13.52764887 -16.6791152  -16.50715856 -17.81799934
#  -26.56182083 -12.75832422 -19.44155762 -28.90327367 -13.70274694
#  -29.4270914  -11.56574199 -26.85778644  -7.96677535  -6.70208925
#  -32.62566022 -19.98949793  -4.02554228 -13.12278233 -23.1394284
#   -1.59030571]
# (31,)
# Next proposed input: [0.400989 0.278541 0.491673 0.336468]

# %%
# Function 5
# ******** Best outcome from week 1 *****
input_data_5 = np.load('initial_data/function_5/initial_inputs.npy')
output_data_5 = np.load('initial_data/function_5/initial_outputs.npy')
input_data_5 = np.append(input_data_5, [[0.240893, 0.843693, 0.902123, 0.884136]], axis=0)
output_data_5 = np.append(output_data_5, 1219.608721581588)
print(input_data_5)
print(input_data_5.shape)
print(output_data_5)
print(output_data_5.shape)

real_noise_std = 1e-10 
noise_assumption = 1e-10
rbf_lengthscale = 0.2

#Acquisition function parameter
beta = 0.3 # made very low to target single peak

#Define kernel of GP
kernel = RBF(length_scale=rbf_lengthscale, length_scale_bounds='fixed')
model = GaussianProcessRegressor(kernel = kernel, alpha=noise_assumption)

X = input_data_5
y = output_data_5
Y = (y - y.mean()) / y.std() # scale to support tiny numbers

model = GaussianProcessRegressor(kernel = kernel)

#Fit the GP model
model.fit(X, Y)

# UCB acquisition
def acquisition(x):
    x = x.reshape(1, -1)
    post_mean, post_std = model.predict(x, return_std=True)
    return post_mean + beta * post_std


# Find Next Point
def propose_next(gp, bounds, n_restarts=8):
    best_x = None
    best_val = -np.inf

    for _ in range(n_restarts):
        x0 = np.random.uniform(0, 1, size=4)

        res = minimize(
            lambda x: -acquisition(x),  # maximise UCB
            x0=x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = acquisition(res.x)

        if val > best_val:
            best_val = val
            best_x = res.x

    return np.round(best_x, decimals=6)

# Get Next Point
bounds = [(0, 1), (0, 1), (0, 1), (0, 1)]
x_next = propose_next(model, bounds)
print("Next proposed input:", x_next)
# Out:
# [[0.19144708 0.03819337 0.60741781 0.41458414]
#  [0.75865295 0.53651774 0.65600038 0.36034155]
#  [0.43834987 0.8043397  0.21024527 0.15129482]
#  [0.70605083 0.53419196 0.26424335 0.48208755]
#  [0.83647799 0.19360965 0.6638927  0.78564888]
#  [0.68343225 0.11866264 0.82904591 0.56757661]
#  [0.55362148 0.66734998 0.32380582 0.81486975]
#  [0.35235627 0.32224153 0.11697937 0.47311252]
#  [0.15378571 0.72938169 0.42259844 0.44307417]
#  [0.46344227 0.63002451 0.10790646 0.9576439 ]
#  [0.67749115 0.35850951 0.47959222 0.07288048]
#  [0.58397341 0.14724265 0.34809746 0.42861465]
#  [0.30688872 0.31687813 0.62263448 0.09539906]
#  [0.51114177 0.817957   0.72871042 0.11235362]
#  [0.43893338 0.77409176 0.37816709 0.93369621]
#  [0.22418902 0.84648049 0.87948418 0.87851568]
#  [0.72526172 0.47987049 0.08894684 0.75976022]
#  [0.35548161 0.63961937 0.41761768 0.12260384]
#  [0.11987923 0.86254031 0.64333133 0.84980383]
#  [0.12688467 0.15342962 0.77016219 0.19051811]
#  [0.240893   0.843693   0.902123   0.884136  ]]
# (21, 4)
# [6.44434399e+01 1.83013796e+01 1.12939795e-01 4.21089813e+00
#  2.58370525e+02 7.84343889e+01 5.75715369e+01 1.09571876e+02
#  8.84799176e+00 2.33223610e+02 2.44230883e+01 6.44201468e+01
#  6.34767158e+01 7.97291299e+01 3.55806818e+02 1.08885962e+03
#  2.88667516e+01 4.51815703e+01 4.31612757e+02 9.97233189e+00
#  1.21960872e+03]
# (21,)
# Next proposed input: [0.317538 0.830816 0.999037 0.910426]

# %%
# Function 6
# In week 1, I made the mistake of handling this task as a minimization problem instead of maximization
# This is now corrected in this week's solution and anticipate to get the best outcome
# ******** Wrong outcome from week 1 (Opposite side) *****
input_data_6 = np.load('initial_data/function_6/initial_inputs.npy')
output_data_6 = np.load('initial_data/function_6/initial_outputs.npy')
input_data_6 = np.append(input_data_6, [[0.121112, 0.747291, 0.134791, 0.181530, 0.905414]], axis=0)
output_data_6 = np.append(output_data_6, -2.541717267047471)
print(input_data_6)
print(input_data_6.shape)
print(output_data_6)
print(output_data_6.shape)

real_noise_std = 1e-10 
noise_assumption = 1e-10
rbf_lengthscale = 0.3

#Acquisition function parameter
beta = 1.96 # moderate peak complexity

#Define kernel of GP
kernel = RBF(length_scale=rbf_lengthscale, length_scale_bounds='fixed')
model = GaussianProcessRegressor(kernel = kernel, alpha=noise_assumption)

X = input_data_6
y = output_data_6
Y = (y - y.mean()) / y.std() # scale to support tiny numbers

model = GaussianProcessRegressor(kernel = kernel)

#Fit the GP model
model.fit(X, Y)

# UCB acquisition
def acquisition(x):
    x = x.reshape(1, -1)
    post_mean, post_std = model.predict(x, return_std=True)
    return post_mean + beta * post_std


# Find Next Point
def propose_next(gp, bounds, n_restarts=10):
    best_x = None
    best_val = -np.inf

    for _ in range(n_restarts):
        x0 = np.random.uniform(0, 1, size=5)

        res = minimize(
            lambda x: -acquisition(x),  # maximise UCB
            x0=x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = acquisition(res.x)

        if val > best_val:
            best_val = val
            best_x = res.x

    return np.round(best_x, decimals=6)

# Get Next Point
bounds = [(0, 1)] * 5 # set based on input dimensions
x_next = propose_next(model, bounds)
print("Next proposed input:", x_next)
# Out:
# [[0.7281861  0.15469257 0.73255167 0.69399651 0.05640131]
#  [0.24238435 0.84409997 0.5778091  0.67902128 0.50195289]
#  [0.72952261 0.7481062  0.67977464 0.35655228 0.67105368]
#  [0.77062024 0.11440374 0.04677993 0.64832428 0.27354905]
#  [0.6188123  0.33180214 0.18728787 0.75623847 0.3288348 ]
#  [0.78495809 0.91068235 0.7081201  0.95922543 0.0049115 ]
#  [0.14511079 0.8966846  0.89632223 0.72627154 0.23627199]
#  [0.94506907 0.28845905 0.97880576 0.96165559 0.59801594]
#  [0.12572016 0.86272469 0.02854433 0.24660527 0.75120624]
#  [0.75759436 0.35583141 0.0165229  0.4342072  0.11243304]
#  [0.5367969  0.30878091 0.41187929 0.38822518 0.5225283 ]
#  [0.95773967 0.23566857 0.09914585 0.15680593 0.07131737]
#  [0.6293079  0.80348368 0.81140844 0.04561319 0.11062446]
#  [0.02173531 0.42808424 0.83593944 0.48948866 0.51108173]
#  [0.43934426 0.69892383 0.42682022 0.10947609 0.87788847]
#  [0.25890557 0.79367771 0.6421139  0.19667346 0.59310318]
#  [0.43216593 0.71561781 0.3418191  0.70499988 0.61496184]
#  [0.78287982 0.53633586 0.44328356 0.85969983 0.01032599]
#  [0.9217762  0.93187122 0.41487637 0.59505727 0.73562569]
#  [0.12667892 0.2914703  0.06452848 0.6805146  0.89281919]
#  [0.121112   0.747291   0.134791   0.18153    0.905414  ]]
# (21, 5)
# [-0.71426495 -1.20995524 -1.67219994 -1.53605771 -0.82923655 -1.24704893
#  -1.23378638 -1.69434344 -2.57116963 -1.30911635 -1.14478485 -1.91267714
#  -1.62283895 -1.35668211 -2.0184254  -1.70255784 -1.29424696 -0.93575656
#  -2.15576776 -1.74688209 -2.54171727]
# (21,)
# Next proposed input: [0.536018 0.367759 0.530592 0.692008 0.201616]

# %%
# Function 7
# ******** Best outcome from week 1 *****
input_data_7 = np.load('initial_data/function_7/initial_inputs.npy')
output_data_7 = np.load('initial_data/function_7/initial_outputs.npy')
input_data_7 = np.append(input_data_7, [[0.018984, 0.392236, 0.325329, 0.152246, 0.349321, 0.732852]], axis=0)
output_data_7 = np.append(output_data_7, 1.7961746346703364)
print(input_data_7)
print(input_data_7.shape)
print(output_data_7)
print(output_data_7.shape)

real_noise_std = 1e-10 
noise_assumption = 1e-10
rbf_lengthscale = 0.3

#Acquisition function parameter
beta = 1.96 # moderate peak complexity

#Define kernel of GP
kernel = RBF(length_scale=rbf_lengthscale, length_scale_bounds='fixed')
model = GaussianProcessRegressor(kernel = kernel, alpha=noise_assumption)

X = input_data_7
y = output_data_7
Y = (y - y.mean()) / y.std() # scale to support tiny numbers

model = GaussianProcessRegressor(kernel = kernel)

#Fit the GP model
model.fit(X, Y)

# UCB acquisition
def acquisition(x):
    x = x.reshape(1, -1)
    post_mean, post_std = model.predict(x, return_std=True)
    return post_mean + beta * post_std


# Find Next Point
def propose_next(gp, bounds, n_restarts=12):
    best_x = None
    best_val = -np.inf

    for _ in range(n_restarts):
        x0 = np.random.uniform(0, 1, size=6)

        res = minimize(
            lambda x: -acquisition(x),  # maximise UCB
            x0=x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = acquisition(res.x)

        if val > best_val:
            best_val = val
            best_x = res.x

    return np.round(best_x, decimals=6)

# Get Next Point
bounds = [(0, 1)] * 6 # set based on input dimensions
x_next = propose_next(model, bounds)
print("Next proposed input:", x_next)
# Out:
# [[0.27262382 0.32449536 0.89710881 0.83295115 0.15406269 0.79586362]
#  [0.54300258 0.9246939  0.34156746 0.64648585 0.71844033 0.34313266]
#  [0.09083225 0.66152938 0.06593091 0.25857701 0.96345285 0.6402654 ]
#  [0.11886697 0.61505494 0.90581639 0.8553003  0.41363143 0.58523563]
#  [0.63021764 0.8380969  0.68001305 0.73189509 0.52673671 0.34842921]
#  [0.76491917 0.25588292 0.60908422 0.21807904 0.32294277 0.09579366]
#  [0.05789554 0.49167222 0.24742222 0.21811844 0.42042833 0.73096984]
#  [0.19525188 0.07922665 0.55458046 0.17056682 0.01494418 0.10703171]
#  [0.64230298 0.83687455 0.02179269 0.10148801 0.68307083 0.6924164 ]
#  [0.78994255 0.19554501 0.57562333 0.07365919 0.25904917 0.05109986]
#  [0.52849733 0.45742436 0.36009569 0.36204551 0.81689098 0.63747637]
#  [0.72261522 0.01181284 0.06364591 0.16517311 0.07924415 0.35995166]
#  [0.07566492 0.33450212 0.13273274 0.60831236 0.91838592 0.82233079]
#  [0.94245084 0.37743962 0.48612233 0.22879108 0.08263175 0.71195755]
#  [0.14864702 0.03394336 0.72880565 0.31606646 0.02176938 0.51691776]
#  [0.81711239 0.54816823 0.10334758 0.12436955 0.72823482 0.44967361]
#  [0.41762629 0.06409998 0.24566877 0.5590408  0.19153138 0.25464092]
#  [0.72628566 0.46489581 0.92457051 0.8072454  0.6354384  0.14341787]
#  [0.31981043 0.52009759 0.29067775 0.87670668 0.49503469 0.6190825 ]
#  [0.87987128 0.39796199 0.00363456 0.95699064 0.26451373 0.11486924]
#  [0.54124078 0.63140314 0.03190205 0.44998156 0.79865282 0.63370429]
#  [0.22634792 0.11502581 0.82474966 0.94538372 0.90531153 0.95101392]
#  [0.68685257 0.04101721 0.00757301 0.285009   0.69156848 0.6555429 ]
#  [0.17597754 0.6244165  0.29554198 0.46955276 0.09776977 0.72814108]
#  [0.88164674 0.20445019 0.41447436 0.42038468 0.26491501 0.73066019]
#  [0.06661051 0.52804507 0.8160952  0.96101714 0.08650933 0.77778822]
#  [0.93246638 0.48881189 0.25860774 0.95624344 0.19042781 0.51985176]
#  [0.84686697 0.14242917 0.06066859 0.75629213 0.5523983  0.08130609]
#  [0.80628208 0.32412237 0.72607601 0.14871213 0.7193764  0.36288398]
#  [0.47682313 0.34094195 0.01433523 0.88013956 0.9986547  0.07966402]
#  [0.018984   0.392236   0.325329   0.152246   0.349321   0.732852  ]]
# (31, 6)
# [0.6044327  0.56275307 0.00750324 0.0614243  0.2730468  0.08374657
#  1.3649683  0.09264495 0.0178696  0.03356494 0.0735163  0.2063097
#  0.00882563 0.26840032 0.61152553 0.01479818 0.27489251 0.06676325
#  0.04211835 0.00270147 0.01820907 0.00701603 0.10050661 0.47539552
#  0.67514163 0.51645722 0.00377748 0.00313433 0.02134252 0.09541116
#  1.79617463]
# (31,)
# Next proposed input: [0.06458  0.291499 0.426406 0.163732 0.339003 0.806973]

# %%
# Function 8
# ******** Best outcome from week 1 *****
input_data_8 = np.load('initial_data/function_8/initial_inputs.npy')
output_data_8 = np.load('initial_data/function_8/initial_outputs.npy')
input_data_8 = np.append(input_data_8, [[0.157347, 0.141981, 0.190491, 0.237306, 0.376975, 0.691764, 0.478713, 0.771636]], axis=0)
output_data_8 = np.append(output_data_8, 9.6902022465459)
print(input_data_8)
print(input_data_8.shape)
print(output_data_8)
print(output_data_8.shape)

real_noise_std = 1e-10 
noise_assumption = 1e-10
rbf_lengthscale = 0.3

#Acquisition function parameter
beta = 1.96 # moderate peak complexity

#Define kernel of GP
kernel = RBF(length_scale=rbf_lengthscale, length_scale_bounds='fixed')
model = GaussianProcessRegressor(kernel = kernel, alpha=noise_assumption)

X = input_data_8
y = output_data_8
Y = (y - y.mean()) / y.std() # scale to support tiny numbers

model = GaussianProcessRegressor(kernel = kernel)

#Fit the GP model
model.fit(X, Y)

# UCB acquisition
def acquisition(x):
    x = x.reshape(1, -1)
    post_mean, post_std = model.predict(x, return_std=True)
    return post_mean + beta * post_std


# Find Next Point
def propose_next(gp, bounds, n_restarts=20):
    best_x = None
    best_val = -np.inf

    for _ in range(n_restarts):
        x0 = np.random.uniform(0, 1, size=8)

        res = minimize(
            lambda x: -acquisition(x),  # maximise UCB
            x0=x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = acquisition(res.x)

        if val > best_val:
            best_val = val
            best_x = res.x

    return np.round(best_x, decimals=6)

# Get Next Point
bounds = [(0, 1)] * 8 # set based on input dimensions
x_next = propose_next(model, bounds)
print("Next proposed input:", x_next)
# Out:
# [[0.60499445 0.29221502 0.90845275 0.35550624 0.20166872 0.57533801
#   0.31031095 0.73428138]
#  [0.17800696 0.56622265 0.99486184 0.21032501 0.32015266 0.70790879
#   0.63538449 0.10713163]
#  [0.00907698 0.81162615 0.52052036 0.07568668 0.26511183 0.09165169
#   0.59241515 0.36732026]
#  [0.50602816 0.65373012 0.36341078 0.17798105 0.0937283  0.19742533
#   0.7558269  0.29247234]
#  [0.35990926 0.24907568 0.49599717 0.70921498 0.11498719 0.28920692
#   0.55729515 0.59388173]
#  [0.77881834 0.0034195  0.33798313 0.51952778 0.82090699 0.53724669
#   0.5513471  0.66003209]
#  [0.90864932 0.0622497  0.23825955 0.76660355 0.13233596 0.99024381
#   0.68806782 0.74249594]
#  [0.58637144 0.88073573 0.74502075 0.54603485 0.00964888 0.74899176
#   0.23090707 0.09791562]
#  [0.76113733 0.85467239 0.38212433 0.33735198 0.68970832 0.30985305
#   0.63137968 0.04195607]
#  [0.9849332  0.69950626 0.9988855  0.18014846 0.58014315 0.23108719
#   0.49082694 0.31368272]
#  [0.11207131 0.43773566 0.59659878 0.59277563 0.22698177 0.41010452
#   0.92123758 0.67475276]
#  [0.79188751 0.57619134 0.69452836 0.28342378 0.13675546 0.27916186
#   0.84276726 0.62532792]
#  [0.1435503  0.93741452 0.23232482 0.00904349 0.41457893 0.40932517
#   0.55377852 0.2058408 ]
#  [0.76991655 0.45875909 0.55900044 0.69460444 0.50319902 0.72834638
#   0.78425353 0.66313109]
#  [0.05644741 0.06595555 0.02292868 0.03878647 0.40393544 0.80105533
#   0.48830701 0.89308498]
#  [0.86243745 0.48273382 0.2818694  0.54410223 0.88749026 0.38265469
#   0.60190199 0.47646169]
#  [0.3515119  0.59006494 0.9094363  0.67840835 0.21282566 0.08846038
#   0.410153   0.19572429]
#  [0.73590364 0.03461189 0.72803027 0.14742652 0.29574314 0.44511731
#   0.97517969 0.37433978]
#  [0.68029397 0.25510465 0.86218799 0.13439582 0.3263292  0.28790687
#   0.43501048 0.36420013]
#  [0.04432925 0.01358149 0.25819824 0.57764416 0.05127992 0.15856307
#   0.59103012 0.07795293]
#  [0.77834548 0.75114565 0.31414221 0.90298577 0.33538166 0.38632267
#   0.74897249 0.9887551 ]
#  [0.89888711 0.5236417  0.87678325 0.21869645 0.90026089 0.28276624
#   0.91107791 0.47239822]
#  [0.14512029 0.11932754 0.42088822 0.38760861 0.15542283 0.87517163
#   0.51055967 0.72861058]
#  [0.33895442 0.56693202 0.3767511  0.09891573 0.65945169 0.24554809
#   0.76248278 0.73215347]
#  [0.17615002 0.29396143 0.97567997 0.79393631 0.92340076 0.03084229
#   0.80325452 0.59589758]
#  [0.02894663 0.02827906 0.48137155 0.6131746  0.67266045 0.02211341
#   0.6014833  0.52488505]
#  [0.19263987 0.63067728 0.41679584 0.49052929 0.79608602 0.65456706
#   0.27624119 0.29551759]
#  [0.94318502 0.21885062 0.72118408 0.42459707 0.986902   0.53518298
#   0.71474318 0.96009372]
#  [0.5327214  0.8336926  0.071399   0.11681148 0.73069311 0.93737559
#   0.86650798 0.127902  ]
#  [0.44709584 0.84395253 0.72954612 0.63915138 0.40928714 0.13264569
#   0.03590888 0.44683847]
#  [0.38222497 0.55713584 0.85310163 0.33379569 0.26572127 0.48087292
#   0.23764706 0.76863196]
#  [0.53281953 0.86230848 0.53826712 0.04944293 0.71970119 0.9067059
#   0.10823094 0.52534791]
#  [0.39486519 0.33180167 0.7407543  0.69786172 0.73740444 0.78377681
#   0.25449546 0.87114551]
#  [0.98594539 0.87305363 0.07039262 0.05358729 0.73415296 0.52025852
#   0.81104004 0.10336036]
#  [0.96457339 0.97397979 0.66375335 0.66221599 0.67312167 0.90523762
#   0.45887462 0.5609175 ]
#  [0.47207071 0.16820264 0.08642757 0.45265551 0.48061922 0.62243949
#   0.92897446 0.11253627]
#  [0.85600695 0.6388937  0.32619202 0.66850311 0.24029837 0.21029889
#   0.16754636 0.96358986]
#  [0.81003174 0.63504604 0.26954758 0.86960534 0.66192159 0.25225873
#   0.76567003 0.89054867]
#  [0.79625252 0.00703653 0.35569738 0.48756605 0.74051962 0.7066501
#   0.99291449 0.38173437]
#  [0.48124533 0.10246072 0.21948594 0.67732237 0.24750919 0.24434086
#   0.16382453 0.71596164]
#  [0.157347   0.141981   0.190491   0.237306   0.376975   0.691764
#   0.478713   0.771636  ]]
# (41, 8)
# [7.3987211  7.00522736 8.45948162 8.28400781 8.60611679 8.54174792
#  7.32743458 7.29987205 7.95787474 5.59219339 7.85454099 6.79198578
#  8.97655402 7.3790829  9.598482   8.15998319 7.13162397 6.76796253
#  7.43374407 9.01307515 7.31089382 5.84106731 9.14163949 8.81755844
#  6.45194313 8.83074505 9.34427428 6.88784639 8.04221254 7.69236805
#  7.92375877 8.42175924 8.2780624  7.11345716 6.40258841 8.47293632
#  7.97768459 7.46087219 7.43659353 9.18300525 9.69020225]
# (41,)
# Next proposed input: [0.041748 0.167371 0.217619 0.143166 0.333341 0.935447 0.502584 0.793127]
